# %%
import side_project
from side_project.stock_analysis_drawkline import *
import configparser

config = configparser.ConfigParser()
config.read('config.ini')
token = config.get('stock', 'token')
stock, month, kline, recent_date = stock_analysis(token, 2330)
stock_analysis_strategy(lambda :bool_strategy(stock), lambda :bool_strategy_one_data(month, stock), stock, kline, recent_date)
# Out:
# C:\Users\CCE\anaconda3\lib\site-packages\FinMind\strategies\base.py:423: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   def final_stats(self) -> pd.Series():
# C:\Users\CCE\anaconda3\lib\site-packages\FinMind\strategies\base.py:450: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   def compare_market_stats(self) -> pd.Series():
# 買入日期：2019-01-02
# 買入價：226.5
# <class 'float'>
# 賣出日期：2019-03-11
# 賣出價：228.0
# 228.0 - 226.5 = 1.5
# 買入日期：2019-03-13
# 買入價：234.0
# <class 'float'>
# 賣出日期：2019-05-07
# 賣出價：259.5
# 259.5 - 234.0 = 25.5
# 買入日期：2019-05-08
# 買入價：260.0
# <class 'float'>
# 賣出日期：2019-05-09
# 賣出價：259.5
# 259.5 - 260.0 = -0.5
# 買入日期：2019-06-11
# 買入價：240.0
# <class 'float'>
# 賣出日期：2019-06-18
# 賣出價：234.0
# 234.0 - 240.0 = -6.0
# 買入日期：2019-06-19
# 買入價：242.5
# ...
