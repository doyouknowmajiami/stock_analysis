# %%
import StockLib
from StockLib.KDStockStrategy import *
from StockLib.MACDStockStrategy import *
from StockLib.MAStockStrategy import *
from StockLib.Stock_lib import *

from FinMind.data import DataLoader
import pandas as pd

#api key
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJkYXRlIjoiMjAyMi0wNS0xMiAwOTowNTo0NyIsInVzZXJfaWQiOiJiZW40NjAyNDE0IiwiaXAiOiIyMjAuMTMyLjE4OS4xNzUifQ.IIZQ5ahmgipp0t-ozgdxcyoAgBdLcPGgsHUuOJdfXVM"
api = DataLoader()
api.login_by_token(api_token=token)
today = str(date.today())
# Out:
# C:\Users\CCE\anaconda3\lib\site-packages\FinMind\strategies\base.py:423: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   def final_stats(self) -> pd.Series():
# C:\Users\CCE\anaconda3\lib\site-packages\FinMind\strategies\base.py:450: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   def compare_market_stats(self) -> pd.Series():

# %%
# api.login_by_token(api_token='token')
# api.login(user_id='user_id',password='password')
stock_name = "2330"
#之後提供，只回測3年，以及從2019-01-01到近期的選擇
stock = api.taiwan_stock_daily(
    stock_id=stock_name,
    start_date='2019-01-01',
    end_date= today
)
recent_date = str(stock["date"].to_numpy().tolist()[-1])
stock
# Out:
#            date stock_id  Trading_Volume  Trading_money   open    max    min  \
# 0    2019-01-02     2330        32900482     7276419230  226.5  226.5  219.0
# 1    2019-01-03     2330        34615620     7459051790  214.0  218.0  214.0
# 2    2019-01-04     2330        67043521    13987136785  211.5  211.5  206.5
# 3    2019-01-07     2330        35695176     7591116569  212.0  214.0  211.0
# 4    2019-01-08     2330        23794481     5019703557  212.0  212.5  210.0
# ..          ...      ...             ...            ...    ...    ...    ...
# 814  2022-05-13     2330        30204773    15412261905  507.0  514.0  506.0
# 815  2022-05-16     2330        22012610    11472463517  521.0  524.0  518.0
# 816  2022-05-17     2330        25812051    13627135311  521.0  533.0  520.0
# 817  2022-05-18     2330        33605299    18075946322  541.0  541.0  534.0
# 818  2022-05-19     2330        40798132    21322524192  523.0  527.0  520.0
#
#      close  spread  Trading_turnover
# 0    219.5    -6.0             12329
# 1    215.5    -4.0             14549
# 2    208.0    -7.5             28786
# 3    213.0     5.0             11224
# 4    211.0    -2.0              9377
# ..     ...     ...               ...
# 814  511.0     6.0             37707
# 815  520.0     9.0             30034
# 816  530.0    10.0             30826
# 817  538.0     8.0             34913
# 818  522.0   -16.0             47232
#
# [819 rows x 10 columns]

# %%
#股價的資料tolist
values = stock[["open", "close", "min", "max"]].to_numpy().tolist()

#月份的資料tolist
data_m = stock[["date"]].to_numpy()
data_m = data_m.flatten()
month = []
for m in data_m:
    month.append(str(m)[:10])

#執行
kline = draw_kline(month, values, stock_name)

# %%
#執行    
#投資策略
macd_strategy(stock)
stock
# Out:
#            date stock_id  Trading_Volume  Trading_money   open    max    min  \
# 0    2019-01-02     2330        32900482     7276419230  226.5  226.5  219.0
# 1    2019-01-03     2330        34615620     7459051790  214.0  218.0  214.0
# 2    2019-01-04     2330        67043521    13987136785  211.5  211.5  206.5
# 3    2019-01-07     2330        35695176     7591116569  212.0  214.0  211.0
# 4    2019-01-08     2330        23794481     5019703557  212.0  212.5  210.0
# ..          ...      ...             ...            ...    ...    ...    ...
# 814  2022-05-13     2330        30204773    15412261905  507.0  514.0  506.0
# 815  2022-05-16     2330        22012610    11472463517  521.0  524.0  518.0
# 816  2022-05-17     2330        25812051    13627135311  521.0  533.0  520.0
# 817  2022-05-18     2330        33605299    18075946322  541.0  541.0  534.0
# 818  2022-05-19     2330        40798132    21322524192  523.0  527.0  520.0
#
#      close  spread  Trading_turnover        DIF       MACD  DIF-MACD
# 0    219.5    -6.0             12329        NaN        NaN       NaN
# 1    215.5    -4.0             14549        NaN        NaN       NaN
# 2    208.0    -7.5             28786        NaN        NaN       NaN
# 3    213.0     5.0             11224        NaN        NaN       NaN
# 4    211.0    -2.0              9377        NaN        NaN       NaN
# ..     ...     ...               ...        ...        ...       ...
# 814  511.0     6.0             37707 -16.232746 -14.431738 -1.801007
# 815  520.0     9.0             30034 -15.520138 -14.649418 -0.870719
# 816  530.0    10.0             30826 -13.987238 -14.516982  0.529744
# 817  538.0     8.0             34913 -11.988673 -14.011320  2.022647
# 818  522.0   -16.0             47232 -11.562576 -13.521572  1.958995
#
# [819 rows x 13 columns]

# %%
buy_date, buy_price, sell_date, sell_price = macd_strategy_data(month, stock) #EMA策略，的買賣點位 **未來要依據策略更改的地方**
profit, loss, ROI = profit_and_loss(buy_price, sell_price) #每次交易虧損、獲利、累積報酬率
buy_sc, sell_sc = draw_scatter(buy_date, buy_price, sell_date, sell_price) #買賣點位的標記
kline.overlap(buy_sc) #買入點位圖疊加
kline.overlap(sell_sc) #賣出點位圖疊加
# Out:
# 買入日期：2019-02-27
# 買入價：239.0
# <class 'float'>
# 賣出日期：2019-03-05
# 賣出價：233.0
# 233.0 - 239.0 = -6.0
# 買入日期：2019-03-20
# 買入價：242.0
# <class 'float'>
# 賣出日期：2019-03-27
# 賣出價：241.5
# 241.5 - 242.0 = -0.5
# 買入日期：2019-04-08
# 買入價：253.0
# <class 'float'>
# 賣出日期：2019-04-29
# 賣出價：259.5
# 259.5 - 253.0 = 6.5
# 買入日期：2019-06-05
# 買入價：235.0
# <class 'float'>
# 賣出日期：2019-08-01
# 賣出價：256.5
# 256.5 - 235.0 = 21.5
# 買入日期：2019-08-23
# 買入價：254.0
# <class 'float'>
# 賣出日期：2019-08-26
# 賣出價：248.5
# 248.5 - 254.0 = -5.5
# 買入日期：2019-08-30
# 買入價：259.0
# <class 'float'>
# 賣出日期：2019-10-25
# 賣出價：293.5
# 293.5 - 259.0 = 34.5
# 買入日期：2019-11-04
# 買入價：307.0
# <class 'float'>
# 賣出日期：2019-11-11
# 賣出價：301.0
# 301.0 - 307.0 = -6.0
# 買入日期：2019-12-11
# 買入價：319.0
# <class 'float'>
# 賣出日期：2019-12-25
# 賣出價：333.0
# 333.0 - 319.0 = 14.0
# 買入日期：2020-02-13
# 買入價：335.0
# <class 'float'>
# 賣出日期：2020-02-18
# 賣出價：322.0
# 322.0 - 335.0 = -13.0
# 買入日期：2020-03-27
# 買入價：273.0
# <class 'float'>
# 賣出日期：2020-05-13
# 賣出價：297.0
# 297.0 - 273.0 = 24.0
# 買入日期：2020-06-03
# 買入價：301.0
# <class 'float'>
# 賣出日期：2020-06-22
# 賣出價：312.0
# 312.0 - 301.0 = 11.0
# 買入日期：2020-07-03
# 買入價：329.5
# <class 'float'>
# 賣出日期：2020-08-11
# 賣出價：429.0
# 429.0 - 329.5 = 99.5
# 買入日期：2020-09-16
# 買入價：458.0
# <class 'float'>
# 賣出日期：2020-09-21
# 賣出價：440.0
# 440.0 - 458.0 = -18.0
# 買入日期：2020-10-08
# 買入價：453.0
# <class 'float'>
# 賣出日期：2020-10-23
# 賣出價：452.0
# 452.0 - 453.0 = -1.0
# 買入日期：2020-11-09
# 買入價：458.5
# <class 'float'>
# 賣出日期：2020-12-01
# 賣出價：490.0
# 490.0 - 458.5 = 31.5
# 買入日期：2020-12-02
# 買入價：499.0
# <class 'float'>
# 賣出日期：2020-12-15
# 賣出價：504.0
# 504.0 - 499.0 = 5.0
# 買入日期：2021-01-04
# 買入價：536.0
# <class 'float'>
# 賣出日期：2021-01-27
# 賣出價：615.0
# 615.0 - 536.0 = 79.0
# 買入日期：2021-02-18
# 買入價：660.0
# <class 'float'>
# 賣出日期：2021-02-19
# 賣出價：652.0
# 652.0 - 660.0 = -8.0
# 買入日期：2021-04-01
# 買入價：602.0
# <class 'float'>
# 賣出日期：2021-04-21
# 賣出價：592.0
# 592.0 - 602.0 = -10.0
# 買入日期：2021-04-27
# 買入價：610.0
# <class 'float'>
# 賣出日期：2021-04-29
# 賣出價：600.0
# 600.0 - 610.0 = -10.0
# 買入日期：2021-05-24
# 買入價：568.0
# <class 'float'>
# 賣出日期：2021-06-22
# 賣出價：578.0
# 578.0 - 568.0 = 10.0
# 買入日期：2021-07-13
# 買入價：607.0
# <class 'float'>
# 賣出日期：2021-07-19
# 賣出價：582.0
# 582.0 - 607.0 = -25.0
# 買入日期：2021-08-03
# 買入價：594.0
# <class 'float'>
# 賣出日期：2021-08-13
# 賣出價：581.0
# 581.0 - 594.0 = -13.0
# 買入日期：2021-08-26
# 買入價：594.0
# <class 'float'>
# 賣出日期：2021-09-15
# 賣出價：607.0
# 607.0 - 594.0 = 13.0
# 買入日期：2021-10-15
# 買入價：600.0
# <class 'float'>
# 賣出日期：2021-11-04
# 賣出價：587.0
# 587.0 - 600.0 = -13.0
# 買入日期：2021-11-05
# 買入價：600.0
# <class 'float'>
# 賣出日期：2021-11-25
# 賣出價：603.0
# 603.0 - 600.0 = 3.0
# 買入日期：2021-12-27
# 買入價：606.0
# <class 'float'>
# 賣出日期：2022-01-21
# 賣出價：641.0
# 641.0 - 606.0 = 35.0
# 買入日期：2022-03-21
# 買入價：586.0
# <class 'float'>
# 賣出日期：2022-04-08
# 賣出價：567.0
# 567.0 - 586.0 = -19.0
# 買入日期：2022-04-20
# 買入價：570.0
# <class 'float'>
# 賣出日期：2022-04-25
# 賣出價：547.0
# 547.0 - 570.0 = -23.0
# 買入日期：2022-05-17
# 買入價：530.0
# 買進次數： 30
# 賣出次數： 29
# 結果 216.5

# %%
#執行
table_1 = draw_table_1(stock, profit, loss, recent_date, buy_date, buy_price, sell_date, sell_price, ROI) #表1-損益分析製作
# Out:
# 總損益：139.800000
# 總獲利：352.200000
# 總虧損：-212.400000
# 總交易次數：29
# 最大交易獲利：97.130000
# 最大交易虧損：-28.440000
# 勝率：0.450000
# 年化報酬率：13.00%
# 未實現損益：-11.090000
# ['139.8', '352.2', '-212.4', '29', '97.13', '-28.44', '45.00%', '13.00%', '-11.09']

# %%
#執行
table_2 = darw_table_2(stock, recent_date, buy_date, buy_price, sell_date, sell_price, ROI)
#表2-交易細節製作
# Out:
#      0           1      2           3      4      5       6       7        8  \
# 0    1  2019-02-27  239.0  2019-03-05  233.0  -7.80  -3.07%  -3.07%  1.34520
# 1    2  2019-03-20  242.0  2019-03-27  241.5  -2.31  -0.79%  -3.85%  1.37797
